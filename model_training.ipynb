# %% [markdown]
# # Image classification

# %% [markdown]
# ## Import TensorFlow and other libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
print(PIL.__version__)
# Out:
# 7.2.0

# %%
batch_size = 32

img_height = 180
img_weight = 180

# %% [markdown]
# using 80% of the images for training, and 20% for validation.

# %%
data_dir='./Training/'

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1440 files belonging to 6 classes.
# Using 1152 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1440 files belonging to 6 classes.
# Using 288 files for validation.

# %% [markdown]
# You can find the class names in the `class_names` attribute on these datasets. These correspond to the directory names in alphabetical order.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Bicycle', 'Boat', 'Cat', 'Motorbike', 'People', 'Table']

# %% [markdown]
# ## Visualize the data
#
# Here are the first 9 images from the training dataset.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ## Configure the dataset for performance
#
# Using buffered prefetching so you can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data.
#
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Standardize the data

# %% [markdown]
# The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network; in general you should seek to make your input values small. Here, you will standardize values to be in the `[0, 1]` range by using a Rescaling layer.

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %% [markdown]
# Note: The Keras Preprocessing utilities and layers introduced in this section are currently experimental and may change.

# %% [markdown]
# There are two ways to use this layer. You can apply it to the dataset by calling map:

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %% [markdown]
# # Create the model
#
# The model consists of three convolution blocks with a max pool layer in each of them. There's a fully connected layer with 128 units on top of it that is activated by a `relu` activation function. This model has not been tuned for high accuracy, the goal of this tutorial is to show a standard approach.

# %%
num_classes = 6

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ## Compile the model
#
# Using the `optimizers.Adam` optimizer and `losses.SparseCategoricalCrossentropy` loss function. To view training and validation accuracy for each training epoch, pass the `metrics` argument.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ## Model summary
#
# View all the layers of the network using the model's `summary` method:

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_2 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 3,989,414
# Trainable params: 3,989,414
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 36/36 [==============================] - 12s 331ms/step - loss: 1.8163 - accuracy: 0.1936 - val_loss: 1.7578 - val_accuracy: 0.2257
# Epoch 2/10
# 36/36 [==============================] - 11s 319ms/step - loss: 1.6228 - accuracy: 0.3290 - val_loss: 1.6300 - val_accuracy: 0.3646
# Epoch 3/10
# 36/36 [==============================] - 12s 320ms/step - loss: 1.3649 - accuracy: 0.4792 - val_loss: 1.6838 - val_accuracy: 0.3368
# Epoch 4/10
# 36/36 [==============================] - 12s 326ms/step - loss: 0.9719 - accuracy: 0.6493 - val_loss: 1.9220 - val_accuracy: 0.3507
# Epoch 5/10
# 36/36 [==============================] - 12s 329ms/step - loss: 0.5556 - accuracy: 0.8212 - val_loss: 2.8790 - val_accuracy: 0.3056
# Epoch 6/10
# 36/36 [==============================] - 12s 323ms/step - loss: 0.3043 - accuracy: 0.9097 - val_loss: 3.2359 - val_accuracy: 0.3229
# Epoch 7/10
# 36/36 [==============================] - 12s 324ms/step - loss: 0.1495 - accuracy: 0.9688 - val_loss: 3.9591 - val_accuracy: 0.2847
# Epoch 8/10
# 36/36 [==============================] - 12s 336ms/step - loss: 0.1103 - accuracy: 0.9783 - val_loss: 4.6423 - val_accuracy: 0.3194
# Epoch 9/10
# 36/36 [==============================] - 12s 325ms/step - loss: 0.0926 - accuracy: 0.9792 - val_loss: 4.9980 - val_accuracy: 0.3333
# Epoch 10/10
# 36/36 [==============================] - 12s 327ms/step - loss: 0.0525 - accuracy: 0.9931 - val_loss: 5.1521 - val_accuracy: 0.3090

# %% [markdown]
# ## Visualize training results

# %% [markdown]
# Create plots of loss and accuracy on the training and validation sets.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Data augmentation

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %% [markdown]
# Let's visualize what a few augmented examples look like by applying data augmentation to the same image several times:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# You will use data augmentation to train a model in a moment.

# %% [markdown]
# ## Dropout
#
# Another technique to reduce overfitting is to introduce [Dropout](https://developers.google.com/machine-learning/glossary#dropout_regularization) to the network, a form of *regularization*.
#
# When you apply Dropout to a layer it randomly drops out (by setting the activation to zero) a number of output units from the layer during the training process. Dropout takes a fractional number as its input value, in the form such as 0.1, 0.2, 0.4, etc. This means dropping out 10%, 20% or 40% of the output units randomly from the applied layer.
#
# Let's create a new neural network using `layers.Dropout`, then train it using augmented images.

# %%
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ## Compile and train the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_2 (Sequential)    (None, 180, 180, 3)       0
# _________________________________________________________________
# rescaling_3 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 3,989,414
# Trainable params: 3,989,414
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 25
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/25
# 36/36 [==============================] - 13s 349ms/step - loss: 1.1492 - accuracy: 0.5720 - val_loss: 1.8077 - val_accuracy: 0.4097
# Epoch 2/25
# 36/36 [==============================] - 13s 351ms/step - loss: 1.1435 - accuracy: 0.5764 - val_loss: 1.7738 - val_accuracy: 0.3958
# Epoch 3/25
# 36/36 [==============================] - 13s 356ms/step - loss: 1.1094 - accuracy: 0.5816 - val_loss: 1.6751 - val_accuracy: 0.4167
# Epoch 4/25
# 36/36 [==============================] - 13s 357ms/step - loss: 1.0775 - accuracy: 0.6016 - val_loss: 1.8105 - val_accuracy: 0.4097
# Epoch 5/25
# 36/36 [==============================] - 13s 357ms/step - loss: 0.9981 - accuracy: 0.6198 - val_loss: 1.8398 - val_accuracy: 0.4479
# Epoch 6/25
# 36/36 [==============================] - 13s 357ms/step - loss: 1.0048 - accuracy: 0.6311 - val_loss: 1.8573 - val_accuracy: 0.3924
# Epoch 7/25
# 36/36 [==============================] - 15s 431ms/step - loss: 0.9291 - accuracy: 0.6719 - val_loss: 1.8248 - val_accuracy: 0.4375
# Epoch 8/25
# 36/36 [==============================] - 16s 440ms/step - loss: 0.9190 - accuracy: 0.6597 - val_loss: 1.9569 - val_accuracy: 0.4306
# Epoch 9/25
# 36/36 [==============================] - 16s 438ms/step - loss: 0.8771 - accuracy: 0.6719 - val_loss: 2.0672 - val_accuracy: 0.4062
# Epoch 10/25
# 36/36 [==============================] - 16s 437ms/step - loss: 0.8873 - accuracy: 0.6823 - val_loss: 2.2946 - val_accuracy: 0.3750
# Epoch 11/25
# 36/36 [==============================] - 16s 435ms/step - loss: 0.8182 - accuracy: 0.6953 - val_loss: 2.2339 - val_accuracy: 0.3646
# Epoch 12/25
# 36/36 [==============================] - 16s 454ms/step - loss: 0.7836 - accuracy: 0.7066 - val_loss: 2.1602 - val_accuracy: 0.4097
# Epoch 13/25
# 36/36 [==============================] - 16s 437ms/step - loss: 0.7926 - accuracy: 0.7196 - val_loss: 2.4439 - val_accuracy: 0.3993
# Epoch 14/25
# 36/36 [==============================] - 16s 449ms/step - loss: 0.7453 - accuracy: 0.7179 - val_loss: 2.3940 - val_accuracy: 0.3993
# Epoch 15/25
# 36/36 [==============================] - 16s 443ms/step - loss: 0.6875 - accuracy: 0.7405 - val_loss: 2.6915 - val_accuracy: 0.3646
# Epoch 16/25
# 36/36 [==============================] - 16s 438ms/step - loss: 0.6949 - accuracy: 0.7457 - val_loss: 2.3982 - val_accuracy: 0.3819
# Epoch 17/25
# 36/36 [==============================] - 16s 440ms/step - loss: 0.6820 - accuracy: 0.7491 - val_loss: 2.3888 - val_accuracy: 0.4132
# Epoch 18/25
# 36/36 [==============================] - 16s 437ms/step - loss: 0.6380 - accuracy: 0.7734 - val_loss: 2.4535 - val_accuracy: 0.3750
# Epoch 19/25
# 36/36 [==============================] - 16s 436ms/step - loss: 0.6219 - accuracy: 0.7700 - val_loss: 2.4375 - val_accuracy: 0.4201
# Epoch 20/25
# 36/36 [==============================] - 16s 435ms/step - loss: 0.5958 - accuracy: 0.7934 - val_loss: 2.7364 - val_accuracy: 0.3889
# Epoch 21/25
# 36/36 [==============================] - 16s 438ms/step - loss: 0.5454 - accuracy: 0.7934 - val_loss: 3.0987 - val_accuracy: 0.3611
# Epoch 22/25
# 36/36 [==============================] - 16s 434ms/step - loss: 0.5577 - accuracy: 0.8047 - val_loss: 2.6846 - val_accuracy: 0.3785
# Epoch 23/25
# 36/36 [==============================] - 16s 436ms/step - loss: 0.5732 - accuracy: 0.8116 - val_loss: 3.0617 - val_accuracy: 0.3576
# Epoch 24/25
# 36/36 [==============================] - 16s 439ms/step - loss: 0.4763 - accuracy: 0.8359 - val_loss: 2.9200 - val_accuracy: 0.3785
# Epoch 25/25
# 36/36 [==============================] - 16s 437ms/step - loss: 0.4681 - accuracy: 0.8377 - val_loss: 3.1124 - val_accuracy: 0.3715

# %%
model.save('./models/model_37percent')
# Out:
# INFO:tensorflow:Assets written to: ./models/model_37percent/assets

# %%
from tensorflow import keras
model1 = keras.models.load_model('./models/model_37percent/')

# %% [markdown]
# ## Visualize training results
#
# After applying data augmentation and Dropout, there is less overfitting than before, and training and validation accuracy are closer aligned.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Predict on new data

# %% [markdown]
# Finally, let's use our model to classify an image that wasn't included in the training or validation sets.

# %% [markdown]
# Note: Data augmentation and Dropout layers are inactive at inference time.

# %%
#sunflower_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/592px-Red_sunflower.jpg"
sunflower_path = './Testing/2015_00422.jpg'

img = keras.preprocessing.image.load_img(
    sunflower_path, target_size=(img_height, img_width)
)
print(img.size)
img_array= keras.preprocessing.image.img_to_array(img)
print(img_array.shape)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# (180, 180)
# (180, 180, 3)
# This image most likely belongs to Bicycle with a 78.90 percent confidence.

# %%
boat_path = './Testing/2015_01061.jpg'

img = keras.preprocessing.image.load_img(
    boat_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
print(img_array.shape)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# (180, 180, 3)
# This image most likely belongs to Boat with a 81.63 percent confidence.

# %%
table_path = './Testing/2015_07281.jpg'
img = keras.preprocessing.image.load_img(
    table_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to Motorbike with a 59.13 percent confidence.

# %%
table_path = './Testing/2015_07303.jpg'
img = keras.preprocessing.image.load_img(
    table_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to Table with a 99.24 percent confidence.

# %%
table_path = './Testing/2015_07289.jpg'
img = keras.preprocessing.image.load_img(
    table_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to Motorbike with a 85.73 percent confidence.

# %%
table_path = './Testing/2015_07283.jpg'
img = keras.preprocessing.image.load_img(
    table_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to Table with a 42.04 percent confidence.

# %%
table_path = './Testing/2015_07298.jpg'
img = keras.preprocessing.image.load_img(
    table_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model1.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
# Out:
# This image most likely belongs to People with a 73.60 percent confidence.
